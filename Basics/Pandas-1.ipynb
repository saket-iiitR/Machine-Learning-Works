# %% [markdown]
# <h1>Pandas-1</h1>
# <h6>Saket Tiwari</h6>
# Date: 06 June 2019

# %%
#pandas are used when we have strings
#we cannot use strings in numpy

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
! pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('data/data/gapminder.tsv',sep='\t')

# %%
#in pandas 1-D :Series 2-D: DataFrame

# %%
df.head(3)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710

# %%
df.tail(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
#shape is an attribute describing properties
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 66.6+ KB

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
df.columns
#it is also a property
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.columns=['country', 'continent', 'year', 'lifeExp', 'population', 'gdpPercap']
df.head()
# Out:
#        country continent  year  lifeExp  population   gdpPercap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
df.keys()
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'population', 'gdpPercap'], dtype='object')

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df[['country','continent']].head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1  Afghanistan      Asia
# 2  Afghanistan      Asia
# 3  Afghanistan      Asia
# 4  Afghanistan      Asia

# %%
df.drop('population',axis=1,inplace=True)
#axis telss that delete the value from every row

# %%
df.head()
# Out:
#        country continent  year  lifeExp   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  779.445314
# 1  Afghanistan      Asia  1957   30.332  820.853030
# 2  Afghanistan      Asia  1962   31.997  853.100710
# 3  Afghanistan      Asia  1967   34.020  836.197138
# 4  Afghanistan      Asia  1972   36.088  739.981106

# %%
df=pd.read_csv('data/data/gapminder.tsv',sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
#iloc is used when working with index
#loc is used when working with label

# %%
df.loc[10]
# Out:
# country      Afghanistan
# continent           Asia
# year                2002
# lifeExp           42.129
# pop             25268405
# gdpPercap        726.734
# Name: 10, dtype: object

# %%
df.loc[[10,100]]
# Out:
#          country continent  year  lifeExp       pop   gdpPercap
# 10   Afghanistan      Asia  2002   42.129  25268405  726.734055
# 100   Bangladesh      Asia  1972   45.252  70759295  630.233627

# %%
df.iloc[-1] #because -1 represents the ;last index
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
#df.loc[-1]#gives error because no label with -1

# %%
df.loc[2:7]
#7 is included
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945

# %%
df.iloc[2:7] #7not included
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439

# %%
df.iloc[3:7,1:4]
# Out:
#   continent  year  lifeExp
# 3      Asia  1967   34.020
# 4      Asia  1972   36.088
# 5      Asia  1977   38.438
# 6      Asia  1982   39.854

# %%
df.loc[3:7,['country','year']]
#since labels are strings therefore we cannot use 1:4 here
# Out:
#        country  year
# 3  Afghanistan  1967
# 4  Afghanistan  1972
# 5  Afghanistan  1977
# 6  Afghanistan  1982
# 7  Afghanistan  1987

# %%
df.loc[3:7,:]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945

# %%
df.iloc[[1,10,100],[0,2,3]]
# Out:
#          country  year  lifeExp
# 1    Afghanistan  1957   30.332
# 10   Afghanistan  2002   42.129
# 100   Bangladesh  1972   45.252

# %%
m=df['lifeExp'].mean()
#df['lifeExp'] is a series and all the operations in numpy
#it is not a right way to calculate mean for categorical data
#we use weighted mean ther

# %%
a=df['lifeExp']>59
a.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: lifeExp, dtype: bool

# %%
df.loc[df.lifeExp>59].head()
# Out:
#     country continent  year  lifeExp      pop    gdpPercap
# 13  Albania    Europe  1957    59.28  1476505  1942.284244
# 14  Albania    Europe  1962    64.82  1728137  2312.888958
# 15  Albania    Europe  1967    66.22  1984060  2760.196931
# 16  Albania    Europe  1972    67.69  2263554  3313.422188
# 17  Albania    Europe  1977    68.93  2509048  3533.003910

# %%
df.loc[df.lifeExp>m].head()
# Out:
#     country continent  year  lifeExp      pop    gdpPercap
# 14  Albania    Europe  1962    64.82  1728137  2312.888958
# 15  Albania    Europe  1967    66.22  1984060  2760.196931
# 16  Albania    Europe  1972    67.69  2263554  3313.422188
# 17  Albania    Europe  1977    68.93  2509048  3533.003910
# 18  Albania    Europe  1982    70.42  2780097  3630.880722

# %%
df.loc[df.lifeExp>59, ['lifeExp','country']].head()
# Out:
#     lifeExp  country
# 13    59.28  Albania
# 14    64.82  Albania
# 15    66.22  Albania
# 16    67.69  Albania
# 17    68.93  Albania

# %%
df.loc[(df.lifeExp>51) & (df.lifeExp<53)]
# Out:
#                     country continent  year  lifeExp        pop     gdpPercap
# 27                  Algeria    Africa  1967   51.407   12760499   3246.991771
# 103              Bangladesh      Asia  1987   52.819  103764241    751.979403
# 127                   Benin    Africa  1987   52.337    4243788   1225.856010
# 158                Botswana    Africa  1962   51.520     512764    983.653976
# 165                Botswana    Africa  1997   52.556    1536536   8647.142313
# 203            Burkina Faso    Africa  2007   52.295   14326203   1217.032994
# 234                Cameroon    Africa  1982   52.961    9250831   2367.983282
# 237                Cameroon    Africa  1997   52.199   14195809   1694.337469
# 271                    Chad    Africa  1987   51.051    5498955    952.386129
# 272                    Chad    Africa  1992   51.724    6429417   1058.064300
# 273                    Chad    Africa  1997   51.573    7562011   1004.961353
# ...

# %%
df.loc[(df.lifeExp<29) | (df.lifeExp>65)].head()
# Out:
#         country continent  year  lifeExp      pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.801  8425333   779.445314
# 15      Albania    Europe  1967   66.220  1984060  2760.196931
# 16      Albania    Europe  1972   67.690  2263554  3313.422188
# 17      Albania    Europe  1977   68.930  2509048  3533.003910
# 18      Albania    Europe  1982   70.420  2780097  3630.880722

# %%
df.loc[df.country=='India']
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 696   India      Asia  1952   37.373   372000000   546.565749
# 697   India      Asia  1957   40.249   409000000   590.061996
# 698   India      Asia  1962   43.605   454000000   658.347151
# 699   India      Asia  1967   47.193   506000000   700.770611
# 700   India      Asia  1972   50.651   567000000   724.032527
# 701   India      Asia  1977   54.208   634000000   813.337323
# 702   India      Asia  1982   56.596   708000000   855.723538
# 703   India      Asia  1987   58.553   788000000   976.512676
# 704   India      Asia  1992   60.223   872000000  1164.406809
# 705   India      Asia  1997   61.765   959000000  1458.817442
# 706   India      Asia  2002   62.879  1034172547  1746.769454
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %%
df.loc[df.country<'India']
# Out:
#               country continent  year  lifeExp       pop     gdpPercap
# 0         Afghanistan      Asia  1952   28.801   8425333    779.445314
# 1         Afghanistan      Asia  1957   30.332   9240934    820.853030
# 2         Afghanistan      Asia  1962   31.997  10267083    853.100710
# 3         Afghanistan      Asia  1967   34.020  11537966    836.197138
# 4         Afghanistan      Asia  1972   36.088  13079460    739.981106
# 5         Afghanistan      Asia  1977   38.438  14880372    786.113360
# 6         Afghanistan      Asia  1982   39.854  12881816    978.011439
# 7         Afghanistan      Asia  1987   40.822  13867957    852.395945
# 8         Afghanistan      Asia  1992   41.674  16317921    649.341395
# 9         Afghanistan      Asia  1997   41.763  22227415    635.341351
# 10        Afghanistan      Asia  2002   42.129  25268405    726.734055
# 11        Afghanistan      Asia  2007   43.828  31889923    974.580338
# ...

# %%
df.loc[df.country>'India']
# Out:
#           country continent  year  lifeExp        pop     gdpPercap
# 708     Indonesia      Asia  1952   37.468   82052000    749.681655
# 709     Indonesia      Asia  1957   39.918   90124000    858.900271
# 710     Indonesia      Asia  1962   42.518   99028000    849.289770
# 711     Indonesia      Asia  1967   45.964  109343000    762.431772
# 712     Indonesia      Asia  1972   49.203  121282000   1111.107907
# 713     Indonesia      Asia  1977   52.702  136725000   1382.702056
# 714     Indonesia      Asia  1982   56.159  153343000   1516.872988
# 715     Indonesia      Asia  1987   60.137  169276000   1748.356961
# 716     Indonesia      Asia  1992   62.681  184816000   2383.140898
# 717     Indonesia      Asia  1997   66.041  199278000   3119.335603
# 718     Indonesia      Asia  2002   68.588  211060000   2873.912870
# 719     Indonesia      Asia  2007   70.650  223547000   3540.651564
# 720          Iran      Asia  1952   44.869   17272000   3035.326002
# ...

# %%
df.groupby('year')['lifeExp','gdpPercap'].mean().reset_index().head()
# Out:
#    year    lifeExp    gdpPercap
# 0  1952  49.057620  3725.276046
# 1  1957  51.507401  4299.408345
# 2  1962  53.609249  4725.812342
# 3  1967  55.678290  5483.653047
# 4  1972  57.647386  6770.082815

# %%
df.groupby(['year','continent'])['lifeExp','gdpPercap'].mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
df.groupby(['continent','year'])['lifeExp','gdpPercap'].mean().reset_index()
# Out:
#    continent  year    lifeExp     gdpPercap
# 0     Africa  1952  39.135500   1252.572466
# 1     Africa  1957  41.266346   1385.236062
# 2     Africa  1962  43.319442   1598.078825
# 3     Africa  1967  45.334538   2050.363801
# 4     Africa  1972  47.450942   2339.615674
# 5     Africa  1977  49.580423   2585.938508
# 6     Africa  1982  51.592865   2481.592960
# 7     Africa  1987  53.344788   2282.668991
# 8     Africa  1992  53.629577   2281.810333
# 9     Africa  1997  53.598269   2378.759555
# 10    Africa  2002  53.325231   2599.385159
# 11    Africa  2007  54.806038   3089.032605
# 12  Americas  1952  53.279840   4079.062552
# 13  Americas  1957  55.960280   4616.043733
# 14  Americas  1962  58.398760   4901.541870
# 15  Americas  1967  60.410920   5668.253496
# 16  Americas  1972  62.394920   6491.334139
# 17  Americas  1977  64.391560   7352.007126
# 18  Americas  1982  66.228840   7506.737088
# 19  Americas  1987  68.090720   7793.400261
# ...

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df.sort_values(['year','lifeExp'],ascending=[1,0])
# Out:
#                        country continent  year  lifeExp        pop  \
# 1140                    Norway    Europe  1952   72.670    3327728
# 684                    Iceland    Europe  1952   72.490     147962
# 1080               Netherlands    Europe  1952   72.130   10381988
# 1464                    Sweden    Europe  1952   71.860    7124673
# 408                    Denmark    Europe  1952   70.780    4334000
# 1476               Switzerland    Europe  1952   69.620    4815000
# 1092               New Zealand   Oceania  1952   69.390    1994794
# 1596            United Kingdom    Europe  1952   69.180   50430000
# 60                   Australia   Oceania  1952   69.120    8691212
# 240                     Canada  Americas  1952   68.750   14785584
# 1608             United States  Americas  1952   68.440  157553000
# 108                    Belgium    Europe  1952   68.000    8730405
# 564                    Germany    Europe  1952   67.500   69145952
# ...
